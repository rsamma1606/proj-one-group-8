# %%
# Pre Req Imports
import pandas as pd
import io

# Define Excel Sheets
xlsx = pd.ExcelFile("Data_Tables_LGA_Recorded_Offences_Year_Ending_December_2022.xlsx")
Crime_By_Police_Region_Pop = pd.read_excel(xlsx, "Table 01") # Offences recorded and rate per 100,000 population by police region and local government area - January 2013 to December 2022
Crime_By_Offence_Type_Pop = pd.read_excel(xlsx, "Table 02") # Offences recorded and rate per 100,000 population by offence type, local government area and police service area - January 2013 to December 2022
Crime_By_Offence_Type = pd.read_excel(xlsx, "Table 03") # Offences recorded by offence type, local government area and postcode or suburb/town - January 2013 to December 2022
Crime_By_Location_Area = pd.read_excel(xlsx, "Table 04") # Offences recorded by location type and local government area - January 2013 to December 2022
Crime_By_Investigation_Status = pd.read_excel(xlsx, "Table 05") # Offences recorded by investigation status and local government area - January 2013 to December 2022
Crime_By_Drugs = pd.read_excel(xlsx, "Table 06") # Select drug offences by drug type and local government area - January 2013 to December 2022

# %%
Crime_By_Drugs
# Out:
#        Year Year ending Local Government Area  \
# 0      2022    December                Alpine
# 1      2022    December                Alpine
# 2      2022    December                Alpine
# 3      2022    December                Ararat
# 4      2022    December                Ararat
# ...     ...         ...                   ...
# 15407  2013    December          Yarra Ranges
# 15408  2013    December          Yarriambiack
# 15409  2013    December          Yarriambiack
# 15410  2013    December          Yarriambiack
# 15411  2013    December          Yarriambiack
#
#                       Offence Subdivision         Offence Group CSA Drug Type  \
# 0             C30 Drug use and possession   C32 Drug possession   Amphetamine
# 1             C30 Drug use and possession   C32 Drug possession      Cannabis
# 2             C30 Drug use and possession   C32 Drug possession       Cocaine
# 3        C10 Drug dealing and trafficking  C12 Drug trafficking      Cannabis
# 4        C10 Drug dealing and trafficking  C12 Drug trafficking       Cocaine
# ...                                   ...                   ...           ...
# 15407         C30 Drug use and possession   C32 Drug possession  Prescription
# 15408    C10 Drug dealing and trafficking  C12 Drug trafficking      Cannabis
# 15409  C20 Cultivate or manufacture drugs   C21 Cultivate drugs     Not Coded
# 15410         C30 Drug use and possession   C32 Drug possession      Cannabis
# 15411         C30 Drug use and possession   C32 Drug possession  Prescription
#
#        Offence Count
# 0                  1
# 1                  5
# 2                  1
# 3                  1
# 4                  3
# ...              ...
# 15407             20
# 15408              1
# 15409              5
# 15410             10
# 15411              2
#
# [15412 rows x 7 columns]
